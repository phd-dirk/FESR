# %%
import numpy as np
import matplotlib.pyplot as plt
data = np.genfromtxt('../configurations/oneWeightDifferentNumsOfS0/w1/fits.csv', delimiter=',', skip_header=2)
s0Vec = np.arange(4, 11, 1)
asVec = data[:,0]
dofChi2Vec = data[:,10]

# %%
fig, ax = plt.subplots()
ax.plot(s0Vec, dofChi2Vec)
plt.show()
